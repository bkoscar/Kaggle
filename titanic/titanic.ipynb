# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
print(f'The dimension of the dataframe is: {df.shape}')
# Out:
# The dimension of the dataframe is: (891, 12)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# Count the number of missing values in percent
missing_values = df.isna().sum()*100/len(df)
df_missing = pd.DataFrame({'columns': df.columns, 'missing_values': round(missing_values,2)}).reset_index(drop = True)
df_missing['missing_values'] = df_missing['missing_values'].apply(lambda x: str(x) + '%')
df_missing
# Out:
#         columns missing_values
# 0   PassengerId           0.0%
# 1      Survived           0.0%
# 2        Pclass           0.0%
# 3          Name           0.0%
# 4           Sex           0.0%
# 5           Age         19.87%
# 6         SibSp           0.0%
# 7         Parch           0.0%
# 8        Ticket           0.0%
# 9          Fare           0.0%
# 10        Cabin          77.1%
# 11     Embarked          0.22%

# %% [markdown]
# The cabin feature present of 77% of missing values, so it will be removed from the analysis. The features like Passengerid, Name and and Ticket don't contribute information

# %%
columns = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Survived']
df = df[columns]
df.head(10)
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Survived
# 0       3    male  22.0      1      0   7.2500        S         0
# 1       1  female  38.0      1      0  71.2833        C         1
# 2       3  female  26.0      0      0   7.9250        S         1
# 3       1  female  35.0      1      0  53.1000        S         1
# 4       3    male  35.0      0      0   8.0500        S         0
# 5       3    male   NaN      0      0   8.4583        Q         0
# 6       1    male  54.0      0      0  51.8625        S         0
# 7       3    male   2.0      3      1  21.0750        S         0
# 8       3  female  27.0      0      2  11.1333        S         1
# 9       2  female  14.0      1      0  30.0708        C         1

# %%
age_mean = df.Age.mean()
age_mean = round(age_mean,0)
df['Age'].fillna(value = age_mean, inplace = True)
df.head(10)
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Survived
# 0       3    male  22.0      1      0   7.2500        S         0
# 1       1  female  38.0      1      0  71.2833        C         1
# 2       3  female  26.0      0      0   7.9250        S         1
# 3       1  female  35.0      1      0  53.1000        S         1
# 4       3    male  35.0      0      0   8.0500        S         0
# 5       3    male  30.0      0      0   8.4583        Q         0
# 6       1    male  54.0      0      0  51.8625        S         0
# 7       3    male   2.0      3      1  21.0750        S         0
# 8       3  female  27.0      0      2  11.1333        S         1
# 9       2  female  14.0      1      0  30.0708        C         1
